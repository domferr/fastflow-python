# %%
import matplotlib.pyplot as plt
n_tasks = 128
subtitle = f"n_tasks = {n_tasks}"
x_axis_workers = [1, 2, 4, 8, 10, 12, 16, 20, 26, 30, 36, 42, 48, 54, 60, 64]

# %% [markdown]
# # ProcessPoolExecutor

# %%
python_poolexec = [155925.58137, 77989.608961, 39488.297665, 19924.934, 16308.217958, 13918.472909, 10377.514601, 9029.969801, 6697.535535, 6512.667557, 5335.967626, 5196.600506, 4294.57049, 4654.557603, 4205.123564, 3716.432886]
"""for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i; done
python multiprocessing = 155925.58137ms
python multiprocessing = 77989.608961ms
python multiprocessing = 39488.297665ms
python multiprocessing = 19924.934ms
python multiprocessing = 16308.217958ms
python multiprocessing = 13918.472909ms
python multiprocessing = 10377.514601ms
python multiprocessing = 9029.969801ms
python multiprocessing = 6697.535535ms
python multiprocessing = 6512.667557ms
python multiprocessing = 5335.967626ms
python multiprocessing = 5196.600506ms
python multiprocessing = 4294.57049ms
python multiprocessing = 4654.557603ms
python multiprocessing = 4205.123564ms
python multiprocessing = 3716.432886ms"""
# Out:
# 'for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i; done\npython multiprocessing = 155925.58137ms\npython multiprocessing = 77989.608961ms\npython multiprocessing = 39488.297665ms\npython multiprocessing = 19924.934ms\npython multiprocessing = 16308.217958ms\npython multiprocessing = 13918.472909ms\npython multiprocessing = 10377.514601ms\npython multiprocessing = 9029.969801ms\npython multiprocessing = 6697.535535ms\npython multiprocessing = 6512.667557ms\npython multiprocessing = 5335.967626ms\npython multiprocessing = 5196.600506ms\npython multiprocessing = 4294.57049ms\npython multiprocessing = 4654.557603ms\npython multiprocessing = 4205.123564ms\npython multiprocessing = 3716.432886ms'

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, python_poolexec, label="ProcessPoolExecutor")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[ProcessPoolExecutor] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Processes

# %%
processes = [161162.194, 80181.307, 40420.791, 20270.064, 16604.525, 14161.592, 10554.274, 9652.413, 7533.135, 7238.467, 6647.543, 5565.654, 5644.378, 5589.542, 5714.834, 4758.398]
"""for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc; done
processes = 161162.194ms, workers = 1
processes = 80181.307ms, workers = 2
processes = 40420.791ms, workers = 4
processes = 20270.064ms, workers = 8
processes = 16604.525ms, workers = 10
processes = 14161.592ms, workers = 12
processes = 10554.274ms, workers = 16
processes = 9652.413ms, workers = 20
processes = 7533.135ms, workers = 26
processes = 7238.467ms, workers = 30
processes = 6647.543ms, workers = 36
processes = 5565.654ms, workers = 42
processes = 5644.378ms, workers = 48
processes = 5589.542ms, workers = 54
processes = 5714.834ms, workers = 60
processes = 4758.398ms, workers = 64"""
# Out:
# 'for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc; done\nprocesses = 161162.194ms, workers = 1\nprocesses = 80181.307ms, workers = 2\nprocesses = 40420.791ms, workers = 4\nprocesses = 20270.064ms, workers = 8\nprocesses = 16604.525ms, workers = 10\nprocesses = 14161.592ms, workers = 12\nprocesses = 10554.274ms, workers = 16\nprocesses = 9652.413ms, workers = 20\nprocesses = 7533.135ms, workers = 26\nprocesses = 7238.467ms, workers = 30\nprocesses = 6647.543ms, workers = 36\nprocesses = 5565.654ms, workers = 42\nprocesses = 5644.378ms, workers = 48\nprocesses = 5589.542ms, workers = 54\nprocesses = 5714.834ms, workers = 60\nprocesses = 4758.398ms, workers = 64'

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, processes, label="Processes")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Processes] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Comparison

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, processes, label="Processes")
plt.plot(x_axis_workers, python_poolexec, label="ProcessPoolExecutor")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)#, ymax=8500)

plt.suptitle('Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %%
res = dict()
res[100] = res.get(100, []); res.get(100).append((1, 590.69)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((1, 591.932)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((1, 589.17)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((1, 610.076)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((1, 623.233)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((1, 1072.373)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((1, 1563.752)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((2, 341.092)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((2, 347.585)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((2, 339.705)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((2, 354.907)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((2, 366.384)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((2, 612.127)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((2, 1050.739)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((4, 237.168)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((4, 237.334)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((4, 228.932)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((4, 235.056)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((4, 240.08)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((4, 664.06)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((4, 1142.5720000000001)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((8, 205.427)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((8, 209.104)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((8, 216.13)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((8, 214.15)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((8, 229.747)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((8, 695.389)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((8, 1155.249)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((10, 215.68)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((10, 213.14)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((10, 209.151)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((10, 228.256)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((10, 227.082)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((10, 718.471)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((10, 1137.296)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((12, 223.57)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((12, 222.625)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((12, 227.517)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((12, 220.978)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((12, 234.877)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((12, 723.449)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((12, 1213.347)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((16, 246.102)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((16, 251.32)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((16, 249.39)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((16, 258.245)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((16, 259.528)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((16, 819.648)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((16, 1250.6)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((20, 271.668)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((20, 269.169)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((20, 268.59)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((20, 283.107)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((20, 305.035)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((20, 843.35)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((20, 1349.233)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((26, 329.716)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((26, 331.198)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((26, 332.896)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((26, 337.121)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((26, 341.723)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((26, 875.576)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((26, 1370.138)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((30, 369.757)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((30, 364.278)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((30, 355.274)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((30, 369.761)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((30, 376.96)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((30, 942.348)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((30, 1439.41)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((36, 435.877)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((36, 427.925)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((36, 442.14)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((36, 445.354)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((36, 438.2)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((36, 967.892)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((36, 1534.091)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((42, 487.147)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((42, 477.256)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((42, 496.45)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((42, 501.41)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((42, 507.031)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((42, 1032.201)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((42, 1549.27)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((48, 566.117)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((48, 530.796)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((48, 532.136)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((48, 553.586)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((48, 562.501)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((48, 1146.841)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((48, 1597.079)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((54, 605.41)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((54, 581.264)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((54, 602.77)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((54, 629.894)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((54, 617.57)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((54, 1131.248)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((54, 1619.27)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((60, 673.529)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((60, 662.37)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((60, 685.251)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((60, 661.479)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((60, 671.474)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((60, 1176.174)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((60, 1654.905)) # bytes = 1048576 ms = 1
res[100] = res.get(100, []); res.get(100).append((64, 682.227)) # bytes = 100 ms = 1
res[512] = res.get(512, []); res.get(512).append((64, 697.636)) # bytes = 512 ms = 1
res[1024] = res.get(1024, []); res.get(1024).append((64, 743.742)) # bytes = 1024 ms = 1
res[8192] = res.get(8192, []); res.get(8192).append((64, 714.186)) # bytes = 8192 ms = 1
res[32768] = res.get(32768, []); res.get(32768).append((64, 699.638)) # bytes = 32768 ms = 1
res[524288] = res.get(524288, []); res.get(524288).append((64, 1258.686)) # bytes = 524288 ms = 1
res[1048576] = res.get(1048576, []); res.get(1048576).append((64, 2089.862)) # bytes = 1048576 ms = 1

final_result = []
for bytes, lis in res.items():
    row = [bytes, []]
    final_result.append(row)
    for (nw, time_ms) in lis:
        row[1].append(time_ms)
    print(row, end=",\n")
# Out:
# [100, [590.69, 341.092, 237.168, 205.427, 215.68, 223.57, 246.102, 271.668, 329.716, 369.757, 435.877, 487.147, 566.117, 605.41, 673.529, 682.227]],
# [512, [591.932, 347.585, 237.334, 209.104, 213.14, 222.625, 251.32, 269.169, 331.198, 364.278, 427.925, 477.256, 530.796, 581.264, 662.37, 697.636]],
# [1024, [589.17, 339.705, 228.932, 216.13, 209.151, 227.517, 249.39, 268.59, 332.896, 355.274, 442.14, 496.45, 532.136, 602.77, 685.251, 743.742]],
# [8192, [610.076, 354.907, 235.056, 214.15, 228.256, 220.978, 258.245, 283.107, 337.121, 369.761, 445.354, 501.41, 553.586, 629.894, 661.479, 714.186]],
# [32768, [623.233, 366.384, 240.08, 229.747, 227.082, 234.877, 259.528, 305.035, 341.723, 376.96, 438.2, 507.031, 562.501, 617.57, 671.474, 699.638]],
# [524288, [1072.373, 612.127, 664.06, 695.389, 718.471, 723.449, 819.648, 843.35, 875.576, 942.348, 967.892, 1032.201, 1146.841, 1131.248, 1176.174, 1258.686]],
# ...
