# %%
import matplotlib.pyplot as plt
n_tasks = 128
subtitle = f"n_tasks = {n_tasks}"
x_axis_workers = [1, 2, 4, 8, 10, 12, 16, 20, 26, 30, 36, 42, 48, 54, 60, 64]

# %% [markdown]
# # ProcessPoolExecutor

# %%
python_poolexec = [155925.58137, 77989.608961, 39488.297665, 19924.934, 16308.217958, 13918.472909, 10377.514601, 9029.969801, 6697.535535, 6512.667557, 5335.967626, 5196.600506, 4294.57049, 4654.557603, 4205.123564, 3716.432886]
"""for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i; done
python multiprocessing = 155925.58137ms
python multiprocessing = 77989.608961ms
python multiprocessing = 39488.297665ms
python multiprocessing = 19924.934ms
python multiprocessing = 16308.217958ms
python multiprocessing = 13918.472909ms
python multiprocessing = 10377.514601ms
python multiprocessing = 9029.969801ms
python multiprocessing = 6697.535535ms
python multiprocessing = 6512.667557ms
python multiprocessing = 5335.967626ms
python multiprocessing = 5196.600506ms
python multiprocessing = 4294.57049ms
python multiprocessing = 4654.557603ms
python multiprocessing = 4205.123564ms
python multiprocessing = 3716.432886ms"""
# Out:
# 'for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i; done\npython multiprocessing = 155925.58137ms\npython multiprocessing = 77989.608961ms\npython multiprocessing = 39488.297665ms\npython multiprocessing = 19924.934ms\npython multiprocessing = 16308.217958ms\npython multiprocessing = 13918.472909ms\npython multiprocessing = 10377.514601ms\npython multiprocessing = 9029.969801ms\npython multiprocessing = 6697.535535ms\npython multiprocessing = 6512.667557ms\npython multiprocessing = 5335.967626ms\npython multiprocessing = 5196.600506ms\npython multiprocessing = 4294.57049ms\npython multiprocessing = 4654.557603ms\npython multiprocessing = 4205.123564ms\npython multiprocessing = 3716.432886ms'

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, python_poolexec, label="ProcessPoolExecutor")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[ProcessPoolExecutor] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Processes

# %%
processes_blocking_mode = [160673.351,80268.963,40725.164,20438.935,16587.203,14159.962,10497.755,9642.017,7565.767,7348.692,6517.033,5527.123,5628.223,5440.471,5515.015,4863.946]
"""for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc -blocking-mode; done
processes = 160673.351ms, workers = 1
processes = 80268.963ms, workers = 2
processes = 40725.164ms, workers = 4
processes = 20438.935ms, workers = 8
processes = 16587.203ms, workers = 10
processes = 14159.962ms, workers = 12
processes = 10497.755ms, workers = 16
processes = 9642.017ms, workers = 20
processes = 7565.767ms, workers = 26
processes = 7348.692ms, workers = 30
processes = 6517.033ms, workers = 36
processes = 5527.123ms, workers = 42
processes = 5628.223ms, workers = 48
processes = 5440.471ms, workers = 54
processes = 5515.015ms, workers = 60
processes = 4863.946ms, workers = 64
"""
# Out:
# 'for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc -blocking-mode; done\nprocesses = 160673.351ms, workers = 1\nprocesses = 80268.963ms, workers = 2\nprocesses = 40725.164ms, workers = 4\nprocesses = 20438.935ms, workers = 8\nprocesses = 16587.203ms, workers = 10\nprocesses = 14159.962ms, workers = 12\nprocesses = 10497.755ms, workers = 16\nprocesses = 9642.017ms, workers = 20\nprocesses = 7565.767ms, workers = 26\nprocesses = 7348.692ms, workers = 30\nprocesses = 6517.033ms, workers = 36\nprocesses = 5527.123ms, workers = 42\nprocesses = 5628.223ms, workers = 48\nprocesses = 5440.471ms, workers = 54\nprocesses = 5515.015ms, workers = 60\nprocesses = 4863.946ms, workers = 64\n'

# %%
processes = [160962.194, 80181.307, 40420.791, 20270.064, 16604.525, 14161.592, 10554.274, 9652.413, 7533.135, 7238.467, 6647.543, 5565.654, 5644.378, 5589.542, 5714.834, 4758.398]
"""for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc; done
run farm of 1 workers to apply image filter to 128 images
blocking mode set to 0
done in 161124.094ms
processes = 161124.094ms, workers = 1
run farm of 2 workers to apply image filter to 128 images
blocking mode set to 0
done in 80498.112ms
processes = 80498.112ms, workers = 2
run farm of 4 workers to apply image filter to 128 images
blocking mode set to 0
done in 40069.597ms
processes = 40069.597ms, workers = 4
run farm of 8 workers to apply image filter to 128 images
blocking mode set to 0
done in 20447.922ms
processes = 20447.922ms, workers = 8
run farm of 10 workers to apply image filter to 128 images
blocking mode set to 0
done in 16615.342ms
processes = 16615.342ms, workers = 10
run farm of 12 workers to apply image filter to 128 images
blocking mode set to 0
done in 14213.608ms
processes = 14213.608ms, workers = 12
run farm of 16 workers to apply image filter to 128 images
blocking mode set to 0
done in 10559.022ms
processes = 10559.022ms, workers = 16
run farm of 20 workers to apply image filter to 128 images
blocking mode set to 0
done in 9640.653ms
processes = 9640.653ms, workers = 20
run farm of 26 workers to apply image filter to 128 images
blocking mode set to 0
done in 7520.698ms
processes = 7520.698ms, workers = 26
run farm of 30 workers to apply image filter to 128 images
blocking mode set to 0
done in 7525.159ms
processes = 7525.159ms, workers = 30
run farm of 36 workers to apply image filter to 128 images
blocking mode set to 0
done in 6707.255ms
processes = 6707.255ms, workers = 36
run farm of 42 workers to apply image filter to 128 images
blocking mode set to 0
done in 5592.368ms
processes = 5592.368ms, workers = 42
run farm of 48 workers to apply image filter to 128 images
blocking mode set to 0
done in 5594.749ms
processes = 5594.749ms, workers = 48
run farm of 54 workers to apply image filter to 128 images
blocking mode set to 0
done in 5614.176ms
processes = 5614.176ms, workers = 54
run farm of 60 workers to apply image filter to 128 images
blocking mode set to 0
done in 5547.8369999999995ms
processes = 5547.8369999999995ms, workers = 60
run farm of 64 workers to apply image filter to 128 images
blocking mode set to 0
done in 4884.236ms
processes = 4884.236ms, workers = 64"""
# Out:
# 'for i in 1 2 4 8 10 12 16 20 26 30 36 42 48 54 60 64; do python3.12 run.py -images 128 -workers $i -proc; done\nrun farm of 1 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 161124.094ms\nprocesses = 161124.094ms, workers = 1\nrun farm of 2 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 80498.112ms\nprocesses = 80498.112ms, workers = 2\nrun farm of 4 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 40069.597ms\nprocesses = 40069.597ms, workers = 4\nrun farm of 8 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 20447.922ms\nprocesses = 20447.922ms, workers = 8\nrun farm of 10 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 16615.342ms\nprocesses = 16615.342ms, workers = 10\nrun farm of 12 workers to apply image filter to 128 images\nblocking mode set to 0\ndone in 14213.608ms\nprocesses = 14213.608ms, workers = 12\nrun farm of 16 workers to a
# ...

# %%
processes_no_mapping = [156331.31,78115.962,39507.024,20147.666,16505.65,14071.738,10532.111,9423.471,7003.803,7004.276,6065.871,6245.392,5598.279,5675.341,5900.665,4879.942,]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, processes, label="Processes")
plt.plot(x_axis_workers, processes_blocking_mode, label="Processes (blocking mode)")
plt.plot(x_axis_workers, processes_no_mapping, label="Processes (no mapping)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Processes] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Comparison

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, python_poolexec, label="ProcessPoolExecutor")
plt.plot(x_axis_workers, processes_no_mapping, label="Processes (no mapping)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)#, ymax=8500)

plt.suptitle('Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(18, 18), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, processes_no_mapping, label="Processes (no mapping)")
plt.plot(x_axis_workers, python_poolexec, label="ProcessPoolExecutor")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)#, ymax=18000)

plt.suptitle('Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %%
fig, axs = plt.subplots(figsize=(18, 9), dpi=500)
plt.bar([f"{i}" for i in x_axis_workers], [processes_no_mapping[i] - python_poolexec[i] for i in range(len(processes_no_mapping))], align='center')
plt.xticks([f"{i}" for i in x_axis_workers], [f"{i}" for i in x_axis_workers])

plt.xlabel("Number of workers")
plt.ylabel("Time difference (msec)")

plt.suptitle('Time difference over number of workers', fontweight="bold")
plt.title(subtitle)
#savefig("stream_service_time")
plt.show()
