# %%
import matplotlib.pyplot as plt
ms = 1
n_tasks = 512
subtitle = f"n_tasks = {n_tasks}, each task is {ms}ms"
x_axis_workers = [1, 2, 4, 8, 10, 12, 16, 20, 26, 30, 36, 42, 48, 54, 60, 64]
target = [(ms * n_tasks)/i for i in x_axis_workers]
print(target)
# Out:
# [512.0, 256.0, 128.0, 64.0, 51.2, 42.666666666666664, 32.0, 25.6, 19.692307692307693, 17.066666666666666, 14.222222222222221, 12.19047619047619, 10.666666666666666, 9.481481481481481, 8.533333333333333, 8.0]

# %% [markdown]
# # Processes

# %%
processes = [
    [100, [594.023, 327.465, 165.722, 268.447, 241.903, 203.809, 184.293, 180.421, 188.936, 408.271, 358.702, 524.578, 373.845, 432.682, 650.524, 901.751]], 
    [512, [596.482, 328.008, 166.059, 263.161, 233.017, 205.168, 248.344, 341.13, 225.316, 388.749, 463.015, 388.606, 430.948, 688.629, 527.461, 641.993]], 
    [1024, [600.409, 342.756, 168.218, 262.012, 240.622, 248.837, 171.218, 344.999, 370.24, 399.06, 370.36, 585.407, 475.506, 639.712, 798.006, 493.631]], 
    [8192, [638.531, 340.369, 192.138, 293.863, 236.156, 296.19, 331.129, 206.314, 371.699, 230.12, 515.999, 549.209, 692.733, 612.84, 514.974, 463.505]], 
    [32768, [744.463, 396.528, 238.906, 326.015, 284.802, 324.618, 414.204, 324.608, 307.748, 530.545, 413.474, 635.486, 773.788, 741.129, 983.586, 1019.85]], 
    [524288, [3164.493, 2722.592, 2602.804, 2596.881, 2621.381, 2673.671, 2748.343, 2796.654, 2702.031, 2878.81, 2970.891, 3022.855, 3215.699, 3492.516, 3362.755, 4762.434]], 
    [1048576, [5879.828, 5464.407, 5262.718, 5231.66, 5250.425, 5192.212, 5202.625, 5286.946, 5275.15, 5221.181, 5644.218, 5639.372, 6010.727, 5639.026, 6269.688, 8544.909]]
]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")
for res in processes:
    kb = 0.1 if res[0] == 100 else res[0] / 1024
    plt.plot(x_axis_workers, res[1], label=f"Processes ({kb} KB)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Processes] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Subinterpreters

# %%
subinterpreters = [
    [100, [620.255, 354.911, 241.131, 223.878, 238.863, 244.707, 283.612, 311.448, 376.446, 418.607, 481.641, 560.081, 648.703, 751.187, 812.339, 839.345]],
    [512, [623.315, 364.359, 250.001, 214.84, 232.175, 241.236, 272.41, 329.531, 369.913, 411.638, 496.944, 555.339, 629.661, 735.325, 815.299, 844.124]],
    [1024, [621.549, 362.991, 254.678, 233.257, 236.719, 253.643, 282.128, 325.891, 368.605, 417.25, 486.544, 573.57, 645.023, 721.646, 787.506, 861.42]],
    [8192, [659.732, 380.914, 252.427, 227.3, 247.534, 261.782, 290.85, 345.874, 398.926, 419.881, 515.483, 587.923, 663.957, 719.184, 808.0, 885.166]],
    [32768, [748.375, 427.661, 274.235, 314.499, 332.84, 321.041, 405.133, 413.597, 493.613, 433.023, 519.993, 704.994, 744.716, 862.988, 804.928, 945.789]],
    [524288, [2703.13, 2178.244, 2248.99, 2284.944, 2336.847, 2329.784, 2419.44, 2462.343, 2526.309, 2568.674, 2724.604, 2764.675, 2850.709, 2914.717, 2620.699, 3730.11]],
    [1048576, [4824.765, 4296.924, 4344.776, 4437.97, 4417.877, 4442.176, 4567.409, 4541.967, 4695.43, 4683.452, 4915.45, 4873.976, 5082.544, 4796.033, 6515.959, 6903.014]],
]

# %%
fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
axs.grid()
# Setting the number of ticks
plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
plt.locator_params(axis='y', nbins=24)
plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")
for res in subinterpreters:
    kb = 0.1 if res[0] == 100 else res[0] / 1024
    plt.plot(x_axis_workers, res[1], label=f"Subinterpreters ({kb} KB)")

axs.set_xlabel("number of workers")
axs.set_ylabel("time (msec)")
axs.set_ylim(ymin=0)

plt.suptitle('[Subinterpreters] Time over number of workers', y=0.97, fontweight="bold")
plt.title(subtitle)
plt.legend()
#savefig("stream_service_time")
plt.show()

# %% [markdown]
# # Comparison

# %%
for i in range(len(subinterpreters)):
    fig, axs = plt.subplots(figsize=(18, 5), dpi=300)
    axs.grid()
    # Setting the number of ticks
    plt.locator_params(axis='x', nbins=len(x_axis_workers)) 
    plt.locator_params(axis='y', nbins=24)
    kb_proc = 0.1 if processes[i][0] == 100 else processes[i][0] / 1024
    kb_sub = 0.1 if subinterpreters[i][0] == 100 else subinterpreters[i][0] / 1024
    plt.plot(x_axis_workers, processes[i][1], label=f"Processes ({kb_proc} KB)")
    plt.plot(x_axis_workers, subinterpreters[i][1], label=f"Subinterpreters ({kb_sub} KB)")
    plt.plot(x_axis_workers, target, ls="dotted", label="Target", color="grey")

    axs.set_xlabel("number of workers")
    axs.set_ylabel("time (msec)")
    axs.set_ylim(ymin=0)#, ymax=8500)

    plt.suptitle('Time over number of workers', y=0.97, fontweight="bold")
    plt.title(f"{subtitle}, task size = {kb_proc} KB")
    plt.legend()
    #savefig("stream_service_time")
    plt.show()

# %%
"""processes = []
processes.append([[1], [594.023]] )#bytes = 100 ms = 1
processes.append([[1], [596.482]] )#bytes = 512 ms = 1
processes.append([[1], [600.409]] )#bytes = 1024 ms = 1
processes.append([[1], [638.531]] )#bytes = 8192 ms = 1
processes.append([[1], [744.463]] )#bytes = 32768 ms = 1
processes.append([[1], [3164.493]])# bytes = 524288 ms = 1
processes.append([[1], [5879.828]] )#bytes = 1048576 ms = 1
processes.append([[2], [327.465]] )#ytes = 100 ms = 1
processes.append([[2], [328.008]] )#ytes = 512 ms = 1
processes.append([[2], [342.756]] )#ytes = 1024 ms = 1
processes.append([[2], [340.369]] )#ytes = 8192 ms = 1
processes.append([[2], [396.528]] )#ytes = 32768 ms = 1
processes.append([[2], [2722.592]] )#bytes = 524288 ms = 1
processes.append([[2], [5464.407]] )#bytes = 1048576 ms = 1
processes.append([[4], [165.722]] )#ytes = 100 ms = 1
processes.append([[4], [166.059]] )#ytes = 512 ms = 1
processes.append([[4], [168.218]] )#ytes = 1024 ms = 1
processes.append([[4], [192.138]] )#ytes = 8192 ms = 1
processes.append([[4], [238.906]] )#ytes = 32768 ms = 1
processes.append([[4], [2602.804]] )#bytes = 524288 ms = 1
processes.append([[4], [5262.718]] )#bytes = 1048576 ms = 1
processes.append([[8], [268.447]] )#ytes = 100 ms = 1
processes.append([[8], [263.161]] )#ytes = 512 ms = 1
processes.append([[8], [262.012]] )#ytes = 1024 ms = 1
processes.append([[8], [293.863]] )#ytes = 8192 ms = 1
processes.append([[8], [326.015]] )#ytes = 32768 ms = 1
processes.append([[8], [2596.881]] )#bytes = 524288 ms = 1
processes.append([[8], [5231.66]] )#ytes = 1048576 ms = 1
processes.append([[10], [241.903]] )#bytes = 100 ms = 1
processes.append([[10], [233.017]] )#bytes = 512 ms = 1
processes.append([[10], [240.622]] )#bytes = 1024 ms = 1
processes.append([[10], [236.156]] )#bytes = 8192 ms = 1
processes.append([[10], [284.802]] )#bytes = 32768 ms = 1
processes.append([[10], [2621.381]])# bytes = 524288 ms = 1
processes.append([[10], [5250.425]])# bytes = 1048576 ms = 1
processes.append([[12], [203.809]] )#bytes = 100 ms = 1
processes.append([[12], [205.168]] )#bytes = 512 ms = 1
processes.append([[12], [248.837]] )#bytes = 1024 ms = 1
processes.append([[12], [296.19]] )#ytes = 8192 ms = 1
processes.append([[12], [324.618]] )#bytes = 32768 ms = 1
processes.append([[12], [2673.671]] )#bytes = 524288 ms = 1
processes.append([[12], [5192.212]] )#bytes = 1048576 ms = 1
processes.append([[16], [184.293]] )#ytes = 100 ms = 1
processes.append([[16], [248.344]] )#ytes = 512 ms = 1
processes.append([[16], [171.218]] )#ytes = 1024 ms = 1
processes.append([[16], [331.129]] )#ytes = 8192 ms = 1
processes.append([[16], [414.204]] )#ytes = 32768 ms = 1
processes.append([[16], [2748.343]] )#bytes = 524288 ms = 1
processes.append([[16], [5202.625]] )#bytes = 1048576 ms = 1
processes.append([[20], [180.421]] )#ytes = 100 ms = 1
processes.append([[20], [341.13]] )#tes = 512 ms = 1
processes.append([[20], [344.999]] )#ytes = 1024 ms = 1
processes.append([[20], [206.314]] )#ytes = 8192 ms = 1
processes.append([[20], [324.608]] )#ytes = 32768 ms = 1
processes.append([[20], [2796.654]])#bytes = 524288 ms = 1
processes.append([[20], [5286.946]])#bytes = 1048576 ms = 1
processes.append([[26], [188.936]] )#ytes = 100 ms = 1
processes.append([[26], [225.316]] )#ytes = 512 ms = 1
processes.append([[26], [370.24]] )#tes = 1024 ms = 1
processes.append([[26], [371.699]] )#ytes = 8192 ms = 1
processes.append([[26], [307.748]] )#ytes = 32768 ms = 1
processes.append([[26], [2702.031]])#bytes = 524288 ms = 1
processes.append([[26], [5275.15]] )#ytes = 1048576 ms = 1
processes.append([[30], [408.271]] )#ytes = 100 ms = 1
processes.append([[30], [388.749]] )#ytes = 512 ms = 1
processes.append([[30], [399.06]] )#tes = 1024 ms = 1
processes.append([[30], [230.12]] )#tes = 8192 ms = 1
processes.append([[30], [530.545]] )#ytes = 32768 ms = 1
processes.append([[30], [2878.81]] )#ytes = 524288 ms = 1
processes.append([[30], [5221.181]] )#bytes = 1048576 ms = 1
processes.append([[36], [358.702]] )#ytes = 100 ms = 1
processes.append([[36], [463.015]] )#ytes = 512 ms = 1
processes.append([[36], [370.36]] )#tes = 1024 ms = 1
processes.append([[36], [515.999]] )#ytes = 8192 ms = 1
processes.append([[36], [413.474]] )#ytes = 32768 ms = 1
processes.append([[36], [2970.891]] )#bytes = 524288 ms = 1
processes.append([[36], [5644.218]] )#bytes = 1048576 ms = 1
processes.append([[42], [524.578]] )#ytes = 100 ms = 1
processes.append([[42], [388.606]] )#ytes = 512 ms = 1
processes.append([[42], [585.407]] )#ytes = 1024 ms = 1
processes.append([[42], [549.209]] )#ytes = 8192 ms = 1
processes.append([[42], [635.486]] )#ytes = 32768 ms = 1
processes.append([[42], [3022.855]] )#bytes = 524288 ms = 1
processes.append([[42], [5639.372]] )#bytes = 1048576 ms = 1
processes.append([[48], [373.845]] )#ytes = 100 ms = 1
processes.append([[48], [430.948]] )#ytes = 512 ms = 1
processes.append([[48], [475.506]] )#ytes = 1024 ms = 1
processes.append([[48], [692.733]] )#ytes = 8192 ms = 1
processes.append([[48], [773.788]] )#ytes = 32768 ms = 1
processes.append([[48], [3215.699]] )#bytes = 524288 ms = 1
processes.append([[48], [6010.727]] )#bytes = 1048576 ms = 1
processes.append([[54], [432.682]] )#ytes = 100 ms = 1
processes.append([[54], [688.629]] )#ytes = 512 ms = 1
processes.append([[54], [639.712]] )#ytes = 1024 ms = 1
processes.append([[54], [612.84]] )#tes = 8192 ms = 1
processes.append([[54], [741.129]] )#ytes = 32768 ms = 1
processes.append([[54], [3492.516]] )#bytes = 524288 ms = 1
processes.append([[54], [5639.026]] )#bytes = 1048576 ms = 1
processes.append([[60], [650.524]] )#ytes = 100 ms = 1
processes.append([[60], [527.461]] )#ytes = 512 ms = 1
processes.append([[60], [798.006]] )#ytes = 1024 ms = 1
processes.append([[60], [514.974]] )#ytes = 8192 ms = 1
processes.append([[60], [983.586]] )#ytes = 32768 ms = 1
processes.append([[60], [3362.755]] )#bytes = 524288 ms = 1
processes.append([[60], [6269.688]] )#bytes = 1048576 ms = 1
processes.append([[64], [901.751]] )#ytes = 100 ms = 1
processes.append([[64], [641.993]] )#ytes = 512 ms = 1
processes.append([[64], [493.631]] )#ytes = 1024 ms = 1
processes.append([[64], [463.505]] )#ytes = 8192 ms = 1
processes.append([[64], [1019.85]] )#ytes = 32768 ms = 1
processes.append([[64], [4762.434]] )#bytes = 524288 ms = 1
processes.append([[64], [8544.909]] )#bytes = 1048576 ms = 1

data = processes
mp = {}
for proc in data:
    mp[proc[0][0]] = []
for proc in data:
    mp[proc[0][0]].append(proc[1][0])
print(mp)
final = []
for i in range(len(mp[proc[0][0]])):
    row = []
    final.append(row)
    for nw, res in mp.items():
        row.append(res[i])
print(final)
"""
# Out:
# 'processes = []\nprocesses.append([[1], [594.023]] )#bytes = 100 ms = 1\nprocesses.append([[1], [596.482]] )#bytes = 512 ms = 1\nprocesses.append([[1], [600.409]] )#bytes = 1024 ms = 1\nprocesses.append([[1], [638.531]] )#bytes = 8192 ms = 1\nprocesses.append([[1], [744.463]] )#bytes = 32768 ms = 1\nprocesses.append([[1], [3164.493]])# bytes = 524288 ms = 1\nprocesses.append([[1], [5879.828]] )#bytes = 1048576 ms = 1\nprocesses.append([[2], [327.465]] )#ytes = 100 ms = 1\nprocesses.append([[2], [328.008]] )#ytes = 512 ms = 1\nprocesses.append([[2], [342.756]] )#ytes = 1024 ms = 1\nprocesses.append([[2], [340.369]] )#ytes = 8192 ms = 1\nprocesses.append([[2], [396.528]] )#ytes = 32768 ms = 1\nprocesses.append([[2], [2722.592]] )#bytes = 524288 ms = 1\nprocesses.append([[2], [5464.407]] )#bytes = 1048576 ms = 1\nprocesses.append([[4], [165.722]] )#ytes = 100 ms = 1\nprocesses.append([[4], [166.059]] )#ytes = 512 ms = 1\nprocesses.append([[4], [168.218]] )#ytes = 1024 ms = 1\nprocesses.
# ...
